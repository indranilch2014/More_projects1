# %% [markdown]
# <a href="https://colab.research.google.com/github/indranilch2014/More_projects1/blob/main/bigquery_connect_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.cloud import bigquery

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/drive/MyDrive/platinum-lead-359620-ddcb79c4bd1b.json'

# %%
client = bigquery.Client()

# %%
sql_query = """
SELECT Certificate, IMDB_Rating, Director, No_of_Votes, Gross, Genre, Released_Year 
FROM `platinum-lead-359620.new_data2.imdb_movies` LIMIT 300
"""

# %%
query_job = client.query(sql_query)
print(query_job)

# %%
query_job.result()

# %%
for row in query_job.result():
   print(row[1:])
# Out:
# (8.1, 'Oriol Paulo', 141516, 1241423, 'Crime', '2016')
# (8.1, 'Jean-Pierre Melville', 45434, 39481, 'Crime', '1967')
# (8.3, 'Mehmet Ada Öztekin', 33935, 7098692, 'Drama', '2019')
# (8.0, 'Asghar Farhadi', 45803, 106662, 'Drama', '2009')
# (7.6, 'Aneesh Chaganty', 140840, 26020957, 'Drama', '2018')
# (8.1, 'Farhan Akhtar', 66803, 300000, 'Comedy', '2001')
# (8.0, 'W.S. Van Dyke', 26642, 2076220, 'Comedy', '1934')
# (7.7, 'James Whale', 30683, 53709, 'Horror', '1933')
# (7.6, 'Brian G. Hutton', 45338, 1378435, 'Adventure', '1970')
# (9.2, 'Francis Ford Coppola', 1620367, 134966411, 'Crime', '1972')
# (9.0, 'Francis Ford Coppola', 1129952, 57300000, 'Crime', '1974')
# (8.9, 'Quentin Tarantino', 1826188, 107928762, 'Crime', '1994')
# (8.6, 'Fernando Meirelles', 699256, 7563397, 'Crime', '2002')
# (8.6, 'Frank Darabont', 1147794, 136801374, 'Crime', '1999')
# (8.6, 'David Fincher', 1445096, 100125643, 'Crime', '1995')
# (8.6, 'Jonathan Demme', 1270197, 130742922, 'Crime', '1991')
# ...
